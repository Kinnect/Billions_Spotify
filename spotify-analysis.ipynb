# %%
#data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

print("Setup Complete")
# Out:
# Setup Complete

# %%
# Used https://exportify.net to export billions club playlist from Spotify by Spotify
# Used https://exportify.net to export Global top songs playlist from Spotify by Spotify
# Track info cames from "Spotify Dataset 1922-2021, ~600k Tracks" https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks by Yamac Eren Ay
# Reference https://developer.spotify.com/documentation/web-api/reference/#endpoint-get-audio-features from Spotify

# %%
top_songs = pd.read_csv('/Users/kevin/Desktop/spotify-top-songs/billions_club.csv')
song_info = pd.read_csv('/Users/kevin/Desktop/spotify-top-songs/tracks.csv')
global_top = pd.read_csv('/Users/kevin/Desktop/spotify-top-songs/top_songs_global.csv')

# %%
top_songs
# Out:
#                                 Track URI                         Track Name  \
# 0    spotify:track:7qiZfU4dY1lWllzX7mPBI3                       Shape of You
# 1    spotify:track:0VjIjW4GlUZAMYd2vXMi3b                    Blinding Lights
# 2    spotify:track:2XU0oxnq2qxCpomAAuJY8K                       Dance Monkey
# 3    spotify:track:0e7ipj03S05BNilyu5bRzt         rockstar (feat. 21 Savage)
# 4    spotify:track:1zi7xx7UVEFkmKfv06H8x0                          One Dance
# ..                                    ...                                ...
# 151  spotify:track:1qPbGZqppFwLwcBC1JQ6Vr                         Wonderwall
# 152  spotify:track:4sPmO7WMQUAf45kwMOtONw                              Hello
# 153  spotify:track:5HkFTCxSeJ3kGNyQJbT4rJ         Another One Bites The Dust
# 154  spotify:track:2374M0fQpWi3dLnB54qaLX                             Africa
# 155  spotify:track:6AWe04n4zsYkGKb3Pf7LMk  Bohemian Rhapsody - 2011 Remaster
#
# ...

# %%
song_info
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
top_songs.rename(columns={"Track Name": "name"},inplace=True)
top_songs
# Out:
#                                 Track URI                               name  \
# 0    spotify:track:7qiZfU4dY1lWllzX7mPBI3                       Shape of You
# 1    spotify:track:0VjIjW4GlUZAMYd2vXMi3b                    Blinding Lights
# 2    spotify:track:2XU0oxnq2qxCpomAAuJY8K                       Dance Monkey
# 3    spotify:track:0e7ipj03S05BNilyu5bRzt         rockstar (feat. 21 Savage)
# 4    spotify:track:1zi7xx7UVEFkmKfv06H8x0                          One Dance
# ..                                    ...                                ...
# 151  spotify:track:1qPbGZqppFwLwcBC1JQ6Vr                         Wonderwall
# 152  spotify:track:4sPmO7WMQUAf45kwMOtONw                              Hello
# 153  spotify:track:5HkFTCxSeJ3kGNyQJbT4rJ         Another One Bites The Dust
# 154  spotify:track:2374M0fQpWi3dLnB54qaLX                             Africa
# 155  spotify:track:6AWe04n4zsYkGKb3Pf7LMk  Bohemian Rhapsody - 2011 Remaster
#
# ...

# %%
song_info.rename(columns={"release_date": "Album Release Date"},inplace=True)
song_info.drop('Album Release Date', axis=1, inplace=True)
song_info
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
song_list = pd.merge(top_songs,song_info,on=['name'])
song_list
# Out:
#                                  Track URI             name  \
# 0     spotify:track:7qiZfU4dY1lWllzX7mPBI3     Shape of You
# 1     spotify:track:7qiZfU4dY1lWllzX7mPBI3     Shape of You
# 2     spotify:track:0VjIjW4GlUZAMYd2vXMi3b  Blinding Lights
# 3     spotify:track:2XU0oxnq2qxCpomAAuJY8K     Dance Monkey
# 4     spotify:track:2XU0oxnq2qxCpomAAuJY8K     Dance Monkey
# ...                                    ...              ...
# 1135  spotify:track:2374M0fQpWi3dLnB54qaLX           Africa
# 1136  spotify:track:2374M0fQpWi3dLnB54qaLX           Africa
# 1137  spotify:track:2374M0fQpWi3dLnB54qaLX           Africa
# 1138  spotify:track:2374M0fQpWi3dLnB54qaLX           Africa
# 1139  spotify:track:2374M0fQpWi3dLnB54qaLX           Africa
#
#                               Artist URI(s) Artist Name(s)  \
# 0     spotify:artist:6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 1     spotify:artist:6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 2     spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# ...

# %%
song_list_f = song_list.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
song_list_f.to_csv('test.csv')

# %%
columns_to_drop = ['Track URI', 'Artist URI(s)','Artist Name(s)', 'Album URI', 'Album Name', 'Album Artist URI(s)', 'Album Artist Name(s)','Album Image URL',
    'Disc Number','Track Preview URL','Explicit','Added By','Added At','id','popularity','duration_ms','artists','id_artists']

# %%
song_list_f = song_list_f.drop(columns_to_drop, axis = 1)
song_list_f
# Out:
#                                           name Album Release Date  \
# 0                                 Shape of You         2017-03-03
# 2                              Blinding Lights         2020-03-20
# 3                                 Dance Monkey         2019-10-17
# 9                   rockstar (feat. 21 Savage)         2018-04-27
# 10                                   One Dance         2016-05-06
# ...                                        ...                ...
# 1055  Lose Yourself - From "8 Mile" Soundtrack         2005-12-06
# 1059                                Wonderwall         1995-10-02
# 1074                                     Hello         2016-06-24
# 1124                Another One Bites The Dust         1981-10-26
# 1125                                    Africa         1982-04-08
#
#       Track Number  Track Duration (ms)  Popularity  explicit  danceability  \
# 0                4               233712          86         0         0.825
# ...

# %%
song_list_t = song_list_f.drop(['name','Album Release Date'], axis=1)
song_list_t.index = np.arange(1, len(song_list_t) + 1)
song_list_t.reset_index(inplace=True)
song_list_t = song_list_t.rename(columns = {'index':'Rank'})
song_list_t
# Out:
#      Rank  Track Number  Track Duration (ms)  Popularity  explicit  \
# 0       1             4               233712          86         0
# 1       2             9               200040          94         0
# 2       3             2               209438          86         0
# 3       4             6               218146          84         1
# 4       5            12               173986          85         0
# ..    ...           ...                  ...         ...       ...
# 150   151             6               326466          76         1
# 151   152             3               258906          70         0
# 152   153             1               295493           9         0
# 153   154             3               215933          56         0
# 154   155            10               295893          83         0
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.825   0.652    1    -3.183     0       0.0802       0.58100
# ...

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=song_list_t['Rank'], y=song_list_t['Track Duration (ms)'])
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='Track Duration (ms)'>

# %%
explicit_ratio = song_list_t['explicit'].sum()/155
explicit_ratio
# Out:
# 0.2838709677419355

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=song_list_t['Rank'], y=song_list_t['danceability'])
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='danceability'>

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=song_list_t['Rank'], y=song_list_t['energy'])
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='energy'>

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=song_list_t['Rank'], y=song_list_t['loudness'])
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='loudness'>

# %%
explicit_ratio = song_list_t['mode'].sum()/155
explicit_ratio
# Out:
# 0.6

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=song_list_t['Rank'], y=song_list_t['speechiness'])
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='speechiness'>

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=song_list_t['Rank'], y=song_list_t['acousticness'])
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='acousticness'>

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=song_list_t['Rank'], y=song_list_t['instrumentalness'])
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='instrumentalness'>

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=song_list_t['Rank'], y=song_list_t['liveness'])
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='liveness'>

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=song_list_t['Rank'], y=song_list_t['valence'])
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='valence'>

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=song_list_t['Rank'], y=song_list_t['tempo'])
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='tempo'>

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=song_list_t['Rank'], y=song_list_t['time_signature'])
# Out:
# <AxesSubplot:xlabel='Rank', ylabel='time_signature'>
